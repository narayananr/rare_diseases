# %% [markdown]
# # Rare Disease Genes – Homework 2
# ## Building Your Data Science Portfolio on GitHub
#
# > **📅 Assigned: April 3, 2026 (Class 2) — Due: April 10, 2026**
# > This is next week's homework. You do not need to start today.
# > Complete HW1 first if you haven't already.
#
# ---
#
# In this homework you will create your own GitHub repository — a public portfolio that shows the world your data science work.
#
# **What you'll build:**
# ```
# rare-disease-genomics/
# ├── README.md          ← describes your project
# ├── notebooks/
# │   └── HW1.ipynb      ← your completed homework 1
# └── results/
#     └── findings.md    ← your written summary
# ```
#
# **What you'll submit:** A link to your GitHub repository.
#
# ---

# %% [markdown]
# ## Part 1: Create a GitHub Account
#
# If you already have a GitHub account, skip to Part 2.
#
# 1. Go to **https://github.com**
# 2. Click **Sign up**
# 3. Choose a username — pick something professional, this will be on your portfolio
#    (e.g. `jane-smith`, `jsmith-data`, your name without spaces)
# 4. Use your school email address
# 5. Complete the verification and confirm your email
#
# **Checkpoint:** You should be able to log in at github.com ✓

# %% [markdown]
# ---
# ## Part 2: Create Your Portfolio Repository
#
# A **repository** (repo) is a folder on GitHub that tracks all your files and changes.
#
# **Steps:**
# 1. Click the **+** button in the top-right corner of GitHub
# 2. Select **New repository**
# 3. Fill in the details:
#    - **Repository name:** `rare-disease-genes` (use hyphens, no spaces)
#    - **Description:** `Data analysis of rare disease genes using Python and pandas`
#    - **Visibility:** Public ✓ (so it can be your portfolio)
#    - Check **Add a README file**
# 4. Click **Create repository**
#
# **Checkpoint:** You should see your new repo at `https://github.com/your-username/rare-disease-genes` ✓

# %% [markdown]
# ---
# ## Part 3: Clone Your Repo to Your Computer
#
# **Cloning** downloads your GitHub repo to your computer so you can add files to it.
#
# First, get the clone URL:
# 1. On your repo page, click the green **Code** button
# 2. Make sure **HTTPS** is selected
# 3. Copy the URL — it looks like: `https://github.com/your-username/rare-disease-genes.git`
#
# Then open a terminal and run:
#
# ```bash
# git clone https://github.com/your-username/rare-disease-genes.git
# cd rare-disease-genes
# ```
#
# Replace `your-username` with your actual GitHub username.
#
# **Checkpoint:** Run the command below to verify it worked:

# %%
# Run this to confirm your repo was cloned successfully
# Replace the path with where you cloned your repo
import os

repo_path = '/path/to/rare-disease-genes'   # ← update this

if os.path.exists(repo_path):
    files = os.listdir(repo_path)
    print(f"✓ Repo found! Contents: {files}")
else:
    print("✗ Path not found — check the path and try again")

# %% [markdown]
# ---
# ## Part 4: Set Up Your Folder Structure
#
# In your terminal, inside the `rare-disease-genes` folder, run:
#
# ```bash
# mkdir notebooks
# mkdir results
# ```
#
# This creates two folders:
# - `notebooks/` — where your code lives
# - `results/` — where your written findings go
#
# **Then** copy your completed HW1 notebook into the `notebooks/` folder.
# You can drag and drop the file, or use the terminal:
#
# ```bash
# # Mac/Linux
# cp /path/to/Rare_Disease_Genes_HW1.ipynb notebooks/HW1.ipynb
#
# # Windows
# copy C:\path\to\Rare_Disease_Genes_HW1.ipynb notebooks\HW1.ipynb
# ```
#
# **Checkpoint:** Run this to verify:

# %%
# Verify your folder structure
import os

repo_path = '/path/to/rare-disease-genes'   # ← update this

for folder in ['notebooks', 'results']:
    path = os.path.join(repo_path, folder)
    exists = os.path.exists(path)
    print(f"{'✓' if exists else '✗'} {folder}/")

hw1 = os.path.join(repo_path, 'notebooks', 'HW1.ipynb')
print(f"{'✓' if os.path.exists(hw1) else '✗'} notebooks/HW1.ipynb")

# %% [markdown]
# ---
# ## Part 5: Write Your README
#
# A README is the front page of your portfolio — it's the first thing anyone sees.
# Open `README.md` in a text editor and replace the contents with your own version.
#
# **Use this template** (fill in the `[ ]` sections):
#
# ```markdown
# # Rare Disease Genes — Data Analysis
#
# ## About This Project
# I analyzed a dataset of [how many?] rare diseases and [how many?] genes
# to explore [what question interested you most?].
#
# ## What I Found
# - [One interesting finding from HW1]
# - [Another finding — a gene, disease, or pattern that surprised you]
# - [Something you would want to investigate further]
#
# ## Tools Used
# - Python
# - pandas — for loading and filtering data
# - matplotlib — for creating charts
#
# ## Files
# - `notebooks/HW1.ipynb` — main analysis notebook
# - `results/findings.md` — written summary of findings
#
# ## Data Source
# Data from [Orphadata](https://www.orphadata.com/) and [Ensembl](https://www.ensembl.org/).
# ```
#
# **Tips for a good README:**
# - Write in plain English — pretend you're explaining to a friend
# - Be specific — "I found 21 rare diseases linked to diabetes keywords" is better than "I found some diseases"
# - It doesn't have to be long — clear and honest is better than long and vague

# %% [markdown]
# ---
# ## Part 6: Write Your Findings
#
# Create a file called `findings.md` inside the `results/` folder.
# This is your written report — 1 page is enough.
#
# **Answer these questions in your own words:**
#
# ```markdown
# # My Findings — Rare Disease Genes
#
# ## Dataset Overview
# - How many disease-gene links are in the dataset?
# - How many unique diseases? How many unique genes?
#
# ## What I Explored
# Which keyword did I search for in Exercise 1, and what did I find?
#
# ## Most Interesting Finding
# What surprised me most about the data?
#
# ## Top Genes
# Which gene is linked to the most diseases? Why might that be?
#
# ## Questions I Still Have
# What would I want to investigate next if I had more time?
# ```

# %% [markdown]
# ---
# ## Part 7: Commit and Push to GitHub
#
# Now you'll save your work to GitHub. Open your terminal inside the `rare-disease-genes` folder.
#
# **Step 1 — Configure git** (only needed once):
# ```bash
# git config --global user.name "Your Name"
# git config --global user.email "your-email@example.com"
# ```
#
# **Step 2 — Stage your files:**
# ```bash
# git add notebooks/HW1.ipynb
# git add results/findings.md
# git add README.md
# ```
#
# **Step 3 — Commit with a message:**
# ```bash
# git commit -m "Add HW1 notebook, findings, and README"
# ```
#
# **Step 4 — Push to GitHub:**
# ```bash
# git push
# ```
#
# You'll be asked for your GitHub username and password.
# ⚠️ GitHub doesn't accept your regular password here — use a **Personal Access Token**:
# 1. Go to GitHub → Settings → Developer settings → Personal access tokens → Tokens (classic)
# 2. Click **Generate new token**
# 3. Check the **repo** box → Generate → Copy the token
# 4. Paste it as your password when prompted
#
# **Checkpoint:** Go to `https://github.com/your-username/rare-disease-genes` — you should see your files there ✓

# %% [markdown]
# ---
# ## Part 8: Final Checklist
#
# Before submitting, verify your repo has all of these:
#
# - [ ] Repo is **public** (anyone can see it)
# - [ ] `README.md` is filled in with your own words — not the template placeholder text
# - [ ] `notebooks/HW1.ipynb` is your completed HW1 (with your keyword, your chart, your answers)
# - [ ] `results/findings.md` answers all the questions
# - [ ] Your name or GitHub username is identifiable
#
# **Submit:** Paste your repo URL in the submission form.
# It should look like: `https://github.com/your-username/rare-disease-genes`

# %% [markdown]
# ---
# ## ⭐ Extension: Make It Yours (Optional)
#
# If you finish early, try one of these:
#
# **1. Add a chart image to your README**
# Save a chart from HW1 as a PNG, add it to a `results/` folder, and embed it in README.md:
# ```markdown
# ![Top 10 Genes](results/top_genes_chart.png)
# ```
#
# **2. Add a second analysis**
# Create `notebooks/exploration.ipynb` with a new question you investigate yourself.
#
# **3. Make your repo look professional**
# - Add topics/tags to your repo (click the gear icon on your repo page): `python`, `pandas`, `data-analysis`, `biology`
# - Add a repo description and website link
